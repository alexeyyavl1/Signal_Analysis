# %%
a=70
b=175
c=20
d=85
e=185
f=30
print(a/d)

print(b/e)

print(a/(b/100*b/100))

print(d/(e/100*e/100))
# Out:
# 0.8235294117647058
# 0.9459459459459459
# 22.857142857142858
# 24.83564645726808

# %%
str = "ID123_CH05_F32.5_A0.001_B0.002"
ID = str[2:5]
print(f"Идентификатор пациента: {ID}")
CH = str[8:10]
print(f"Номер канала: {CH}")
F = str[12:16]
print(f"Частота: {F}")
A = str[18:23]
print(f"Амплитуда: {A}")
B = str[-5:]
print(f"Шум: {B}")
# Out:
# Идентификатор пациента: 123
# Номер канала: 05
# Частота: 32.5
# Амплитуда: 0.001
# Шум: 0.002

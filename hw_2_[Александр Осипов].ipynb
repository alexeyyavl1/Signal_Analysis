# %%
#финальный вариант в последней ячейке, здесь я по кускам все разибирал)
patient_data = input ()
parts = patient_data.split(';')
print(parts)
# Out:
# ['Петров', 'Сергей', '1970-11-05', 'A15.0', 'активный']

# %%
(parts[0] and parts[1]).isalpha()
# Out:
# True

# %%
birthday = parts[2]
parts_bd = birthday.split('-')
all(x.isdigit() for x in parts_bd)
# вариант с "олл" мне подсказала нейронка, я долго не врубался как проверить сразу все части

# верно, но можно было пойти проще, через циклы if - else
# Out:
# True

# %%
MKB = parts[3]
MKB[0].isalpha() and (MKB[1] and MKB[-1]).isdigit()
# Out:
# True

# %%
condition = parts[4]
condition == 'активный' or 'ремиссия' or 'выписан'
# Out:
# True

# %%
condition = parts[4]
if condition == 'активный' or 'ремиссия' or 'выписан':
    print (True)
else: print (False)
# Out:
# True

# %%
#final variant

patient_data = input ()
parts = patient_data.split(';')
print(parts)
MKB = parts[3]
condition = parts[4]

parts_bd = parts[2].split('-')
month = int(parts_bd[1])
day = int(parts_bd[2])

if ((parts[0].isalpha and parts[1].isalpha()) and
(all(x.isdigit() for x in parts_bd)) and month<=12 and day<=31 and
#this line was difficult)
(MKB[0].isalpha() and (MKB[1] and MKB[-1]).isdigit()) and 
(condition in ['активный', 'ремиссия', 'выписан'])):

# очень хороший обхрод вложенных циклов if - else, вполне можно использовать 
# тем не менее, можно было бы просто написать несколько вложенных циклов, как тут:
# a = input('Фамилия пациента')
# b = input('Имя пациента')
# c = int (input('Год рождения'))
# d = int (input('Месяц рождения'))
# e = int (input('День рождения'))
# g = input('Диагноз')
# h = input('Статус')
# if d == 9 and e >= 29:
#     print('False')
# elif d == 4 or d == 6 or d == 9 or d == 11 and e == 31:
#     print('False')
# elif a and b.isalpha():
#     if c <= 2025 and d <= 12 and e <= 31:
#         c1 = str(c)
#         d1 = str(d)
#         e1 = str(e)
#         f = '-'.join([c1, d1, e1])
#         if g.startswith('A') or g.startswith('B') or g.startswith('C') and g[-1].isdigit():
#             if 'активный' in h or 'ремиссия' in h or 'выписан' in h:
#                 print(';'.join([a, b, f, g, h]))
#             else :
#                 print('False')
#         else :
#             print('False')
#     else :
#         print('False')
# else :
#     print('False')

    print (True)
else: print (False)
# Out:
# ['Петров', 'Сергей', '1970-11-05', 'A15.0', 'активный']
# True
